# %% [markdown]
# <a href="https://colab.research.google.com/github/saraiva142/tcc/blob/main/An%C3%A1liseExplorat%C3%B3riaTCC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget -r -N -c -np https://physionet.org/files/gaitpdb/1.0.0/
# Out:
# --2025-06-29 22:19:01--  https://physionet.org/files/gaitpdb/1.0.0/
# Resolving physionet.org (physionet.org)... 18.18.42.54
# Connecting to physionet.org (physionet.org)|18.18.42.54|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/index.html’
#
# physionet.org/files     [ <=>                ]  36.17K  --.-KB/s    in 0.03s
#
# Last-modified header missing -- time-stamps turned off.
# 2025-06-29 22:19:01 (1.07 MB/s) - ‘physionet.org/files/gaitpdb/1.0.0/index.html’ saved [37042]
#
# Loading robots.txt; please ignore errors.
# --2025-06-29 22:19:01--  https://physionet.org/robots.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 22 [text/plain]
# Saving to: ‘physionet.org/robots.txt’
#
# physionet.org/robot 100%[===================>]      22  --.-KB/s    in 0s
#
# 2025-06-29 22:19:01 (9.49 MB/s) - ‘physionet.org/robots.txt’ saved [22/22]
#
# --2025-06-29 22:19:01--  https://physionet.org/files/gaitpdb/1.0.0/GaCo01_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1116032 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo01_01.txt’
#
# physionet.org/files 100%[===================>]   1.06M   607KB/s    in 1.8s
#
# 2025-06-29 22:19:03 (607 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo01_01.txt’ saved [1116032/1116032]
#
# --2025-06-29 22:19:03--  https://physionet.org/files/gaitpdb/1.0.0/GaCo02_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1058168 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo02_01.txt’
#
# physionet.org/files 100%[===================>]   1.01M   585KB/s    in 1.8s
#
# 2025-06-29 22:19:05 (585 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo02_01.txt’ saved [1058168/1058168]
#
# --2025-06-29 22:19:05--  https://physionet.org/files/gaitpdb/1.0.0/GaCo02_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1061318 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo02_02.txt’
#
# physionet.org/files 100%[===================>]   1.01M   551KB/s    in 1.9s
#
# 2025-06-29 22:19:07 (551 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo02_02.txt’ saved [1061318/1061318]
#
# --2025-06-29 22:19:07--  https://physionet.org/files/gaitpdb/1.0.0/GaCo03_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1135895 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo03_01.txt’
#
# physionet.org/files 100%[===================>]   1.08M   569KB/s    in 1.9s
#
# 2025-06-29 22:19:09 (569 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo03_01.txt’ saved [1135895/1135895]
#
# --2025-06-29 22:19:09--  https://physionet.org/files/gaitpdb/1.0.0/GaCo03_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1127589 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo03_02.txt’
#
# physionet.org/files 100%[===================>]   1.08M   589KB/s    in 1.9s
#
# 2025-06-29 22:19:11 (589 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo03_02.txt’ saved [1127589/1127589]
#
# --2025-06-29 22:19:11--  https://physionet.org/files/gaitpdb/1.0.0/GaCo04_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1070333 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo04_01.txt’
#
# physionet.org/files 100%[===================>]   1.02M   613KB/s    in 1.7s
#
# 2025-06-29 22:19:13 (613 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo04_01.txt’ saved [1070333/1070333]
#
# --2025-06-29 22:19:13--  https://physionet.org/files/gaitpdb/1.0.0/GaCo04_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1069887 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo04_02.txt’
#
# physionet.org/files 100%[===================>]   1.02M   585KB/s    in 1.8s
#
# 2025-06-29 22:19:15 (585 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo04_02.txt’ saved [1069887/1069887]
#
# --2025-06-29 22:19:15--  https://physionet.org/files/gaitpdb/1.0.0/GaCo05_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1131521 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo05_01.txt’
#
# physionet.org/files 100%[===================>]   1.08M   584KB/s    in 1.9s
#
# 2025-06-29 22:19:17 (584 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo05_01.txt’ saved [1131521/1131521]
#
# --2025-06-29 22:19:17--  https://physionet.org/files/gaitpdb/1.0.0/GaCo05_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1131186 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo05_02.txt’
#
# physionet.org/files 100%[===================>]   1.08M   567KB/s    in 1.9s
#
# 2025-06-29 22:19:19 (567 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo05_02.txt’ saved [1131186/1131186]
#
# --2025-06-29 22:19:19--  https://physionet.org/files/gaitpdb/1.0.0/GaCo06_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1075667 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo06_01.txt’
#
# physionet.org/files 100%[===================>]   1.03M   583KB/s    in 1.8s
#
# 2025-06-29 22:19:21 (583 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo06_01.txt’ saved [1075667/1075667]
#
# --2025-06-29 22:19:21--  https://physionet.org/files/gaitpdb/1.0.0/GaCo06_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1029132 (1005K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo06_02.txt’
#
# physionet.org/files 100%[===================>]   1005K   570KB/s    in 1.8s
#
# 2025-06-29 22:19:23 (570 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo06_02.txt’ saved [1029132/1029132]
#
# --2025-06-29 22:19:23--  https://physionet.org/files/gaitpdb/1.0.0/GaCo07_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1100517 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo07_01.txt’
#
# physionet.org/files 100%[===================>]   1.05M   583KB/s    in 1.8s
#
# 2025-06-29 22:19:25 (583 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo07_01.txt’ saved [1100517/1100517]
#
# --2025-06-29 22:19:25--  https://physionet.org/files/gaitpdb/1.0.0/GaCo07_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1092202 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo07_02.txt’
#
# physionet.org/files 100%[===================>]   1.04M   589KB/s    in 1.8s
#
# 2025-06-29 22:19:27 (589 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo07_02.txt’ saved [1092202/1092202]
#
# --2025-06-29 22:19:27--  https://physionet.org/files/gaitpdb/1.0.0/GaCo08_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1087689 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo08_01.txt’
#
# physionet.org/files 100%[===================>]   1.04M   589KB/s    in 1.8s
#
# 2025-06-29 22:19:29 (589 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo08_01.txt’ saved [1087689/1087689]
#
# --2025-06-29 22:19:29--  https://physionet.org/files/gaitpdb/1.0.0/GaCo08_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1092940 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo08_02.txt’
#
# physionet.org/files 100%[===================>]   1.04M   583KB/s    in 1.8s
#
# 2025-06-29 22:19:31 (583 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo08_02.txt’ saved [1092940/1092940]
#
# --2025-06-29 22:19:31--  https://physionet.org/files/gaitpdb/1.0.0/GaCo09_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1069368 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo09_01.txt’
#
# physionet.org/files 100%[===================>]   1.02M   564KB/s    in 1.9s
#
# 2025-06-29 22:19:33 (564 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo09_01.txt’ saved [1069368/1069368]
#
# --2025-06-29 22:19:33--  https://physionet.org/files/gaitpdb/1.0.0/GaCo09_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1074686 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo09_02.txt’
#
# physionet.org/files 100%[===================>]   1.02M   569KB/s    in 1.8s
#
# 2025-06-29 22:19:35 (569 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo09_02.txt’ saved [1074686/1074686]
#
# --2025-06-29 22:19:35--  https://physionet.org/files/gaitpdb/1.0.0/GaCo10_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1046422 (1022K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo10_01.txt’
#
# physionet.org/files 100%[===================>]   1022K   580KB/s    in 1.8s
#
# 2025-06-29 22:19:37 (580 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo10_01.txt’ saved [1046422/1046422]
#
# --2025-06-29 22:19:37--  https://physionet.org/files/gaitpdb/1.0.0/GaCo10_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1037723 (1013K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo10_02.txt’
#
# physionet.org/files 100%[===================>]   1013K   557KB/s    in 1.8s
#
# 2025-06-29 22:19:39 (557 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo10_02.txt’ saved [1037723/1037723]
#
# --2025-06-29 22:19:39--  https://physionet.org/files/gaitpdb/1.0.0/GaCo11_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1106592 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo11_01.txt’
#
# physionet.org/files 100%[===================>]   1.05M   579KB/s    in 1.9s
#
# 2025-06-29 22:19:41 (579 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo11_01.txt’ saved [1106592/1106592]
#
# --2025-06-29 22:19:41--  https://physionet.org/files/gaitpdb/1.0.0/GaCo12_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1059303 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo12_01.txt’
#
# physionet.org/files 100%[===================>]   1.01M   586KB/s    in 1.8s
#
# 2025-06-29 22:19:42 (586 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo12_01.txt’ saved [1059303/1059303]
#
# --2025-06-29 22:19:42--  https://physionet.org/files/gaitpdb/1.0.0/GaCo13_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1111963 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo13_01.txt’
#
# physionet.org/files 100%[===================>]   1.06M   554KB/s    in 2.0s
#
# 2025-06-29 22:19:45 (554 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo13_01.txt’ saved [1111963/1111963]
#
# --2025-06-29 22:19:45--  https://physionet.org/files/gaitpdb/1.0.0/GaCo13_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1095164 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo13_02.txt’
#
# physionet.org/files 100%[===================>]   1.04M   559KB/s    in 1.9s
#
# 2025-06-29 22:19:47 (559 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo13_02.txt’ saved [1095164/1095164]
#
# --2025-06-29 22:19:47--  https://physionet.org/files/gaitpdb/1.0.0/GaCo13_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1027028 (1003K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo13_10.txt’
#
# physionet.org/files 100%[===================>]   1003K   549KB/s    in 1.8s
#
# 2025-06-29 22:19:49 (549 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo13_10.txt’ saved [1027028/1027028]
#
# --2025-06-29 22:19:49--  https://physionet.org/files/gaitpdb/1.0.0/GaCo14_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1019607 (996K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo14_01.txt’
#
# physionet.org/files 100%[===================>] 995.71K   602KB/s    in 1.7s
#
# 2025-06-29 22:19:50 (602 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo14_01.txt’ saved [1019607/1019607]
#
# --2025-06-29 22:19:50--  https://physionet.org/files/gaitpdb/1.0.0/GaCo14_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1017920 (994K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo14_02.txt’
#
# physionet.org/files 100%[===================>] 994.06K   594KB/s    in 1.7s
#
# 2025-06-29 22:19:52 (594 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo14_02.txt’ saved [1017920/1017920]
#
# --2025-06-29 22:19:52--  https://physionet.org/files/gaitpdb/1.0.0/GaCo14_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1024570 (1001K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo14_10.txt’
#
# physionet.org/files 100%[===================>]   1001K   562KB/s    in 1.8s
#
# 2025-06-29 22:19:54 (562 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo14_10.txt’ saved [1024570/1024570]
#
# --2025-06-29 22:19:54--  https://physionet.org/files/gaitpdb/1.0.0/GaCo15_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1053705 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo15_01.txt’
#
# physionet.org/files 100%[===================>]   1.00M   608KB/s    in 1.7s
#
# 2025-06-29 22:19:56 (608 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo15_01.txt’ saved [1053705/1053705]
#
# --2025-06-29 22:19:56--  https://physionet.org/files/gaitpdb/1.0.0/GaCo15_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1057332 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo15_02.txt’
#
# physionet.org/files 100%[===================>]   1.01M   554KB/s    in 1.9s
#
# 2025-06-29 22:19:58 (554 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo15_02.txt’ saved [1057332/1057332]
#
# --2025-06-29 22:19:58--  https://physionet.org/files/gaitpdb/1.0.0/GaCo15_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1064117 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo15_10.txt’
#
# physionet.org/files 100%[===================>]   1.01M   595KB/s    in 1.7s
#
# 2025-06-29 22:20:00 (595 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo15_10.txt’ saved [1064117/1064117]
#
# --2025-06-29 22:20:00--  https://physionet.org/files/gaitpdb/1.0.0/GaCo16_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1041484 (1017K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo16_01.txt’
#
# physionet.org/files 100%[===================>]   1017K   577KB/s    in 1.8s
#
# 2025-06-29 22:20:02 (577 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo16_01.txt’ saved [1041484/1041484]
#
# --2025-06-29 22:20:02--  https://physionet.org/files/gaitpdb/1.0.0/GaCo16_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1042642 (1018K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo16_02.txt’
#
# physionet.org/files 100%[===================>]   1018K   567KB/s    in 1.8s
#
# 2025-06-29 22:20:03 (567 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo16_02.txt’ saved [1042642/1042642]
#
# --2025-06-29 22:20:03--  https://physionet.org/files/gaitpdb/1.0.0/GaCo16_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 471819 (461K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo16_10.txt’
#
# physionet.org/files 100%[===================>] 460.76K   569KB/s    in 0.8s
#
# 2025-06-29 22:20:04 (569 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo16_10.txt’ saved [471819/471819]
#
# --2025-06-29 22:20:04--  https://physionet.org/files/gaitpdb/1.0.0/GaCo17_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1036962 (1013K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo17_01.txt’
#
# physionet.org/files 100%[===================>]   1013K   565KB/s    in 1.8s
#
# 2025-06-29 22:20:06 (565 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo17_01.txt’ saved [1036962/1036962]
#
# --2025-06-29 22:20:06--  https://physionet.org/files/gaitpdb/1.0.0/GaCo17_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1026477 (1002K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo17_02.txt’
#
# physionet.org/files 100%[===================>]   1002K   558KB/s    in 1.8s
#
# 2025-06-29 22:20:08 (558 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo17_02.txt’ saved [1026477/1026477]
#
# --2025-06-29 22:20:08--  https://physionet.org/files/gaitpdb/1.0.0/GaCo17_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1039738 (1015K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo17_10.txt’
#
# physionet.org/files 100%[===================>]   1015K   583KB/s    in 1.7s
#
# 2025-06-29 22:20:10 (583 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo17_10.txt’ saved [1039738/1039738]
#
# --2025-06-29 22:20:10--  https://physionet.org/files/gaitpdb/1.0.0/GaCo22_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1044712 (1020K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo22_01.txt’
#
# physionet.org/files 100%[===================>]   1020K   561KB/s    in 1.8s
#
# 2025-06-29 22:20:12 (561 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo22_01.txt’ saved [1044712/1044712]
#
# --2025-06-29 22:20:12--  https://physionet.org/files/gaitpdb/1.0.0/GaCo22_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1047246 (1023K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaCo22_10.txt’
#
# physionet.org/files 100%[===================>]   1023K   576KB/s    in 1.8s
#
# 2025-06-29 22:20:14 (576 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaCo22_10.txt’ saved [1047246/1047246]
#
# --2025-06-29 22:20:14--  https://physionet.org/files/gaitpdb/1.0.0/GaPt03_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1118496 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt03_01.txt’
#
# physionet.org/files 100%[===================>]   1.07M   583KB/s    in 1.9s
#
# 2025-06-29 22:20:16 (583 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt03_01.txt’ saved [1118496/1118496]
#
# --2025-06-29 22:20:16--  https://physionet.org/files/gaitpdb/1.0.0/GaPt04_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1150901 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt04_01.txt’
#
# physionet.org/files 100%[===================>]   1.10M   566KB/s    in 2.0s
#
# 2025-06-29 22:20:18 (566 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt04_01.txt’ saved [1150901/1150901]
#
# --2025-06-29 22:20:18--  https://physionet.org/files/gaitpdb/1.0.0/GaPt05_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1063144 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt05_01.txt’
#
# physionet.org/files 100%[===================>]   1.01M   604KB/s    in 1.7s
#
# 2025-06-29 22:20:20 (604 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt05_01.txt’ saved [1063144/1063144]
#
# --2025-06-29 22:20:20--  https://physionet.org/files/gaitpdb/1.0.0/GaPt06_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1139788 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt06_01.txt’
#
# physionet.org/files 100%[===================>]   1.09M   580KB/s    in 1.9s
#
# 2025-06-29 22:20:22 (580 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt06_01.txt’ saved [1139788/1139788]
#
# --2025-06-29 22:20:22--  https://physionet.org/files/gaitpdb/1.0.0/GaPt07_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1130433 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt07_01.txt’
#
# physionet.org/files 100%[===================>]   1.08M   586KB/s    in 1.9s
#
# 2025-06-29 22:20:24 (586 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt07_01.txt’ saved [1130433/1130433]
#
# --2025-06-29 22:20:24--  https://physionet.org/files/gaitpdb/1.0.0/GaPt07_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1065629 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt07_02.txt’
#
# physionet.org/files 100%[===================>]   1.02M   569KB/s    in 1.8s
#
# 2025-06-29 22:20:26 (569 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt07_02.txt’ saved [1065629/1065629]
#
# --2025-06-29 22:20:26--  https://physionet.org/files/gaitpdb/1.0.0/GaPt08_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1066009 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt08_01.txt’
#
# physionet.org/files 100%[===================>]   1.02M   574KB/s    in 1.8s
#
# 2025-06-29 22:20:28 (574 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt08_01.txt’ saved [1066009/1066009]
#
# --2025-06-29 22:20:28--  https://physionet.org/files/gaitpdb/1.0.0/GaPt08_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1059654 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt08_02.txt’
#
# physionet.org/files 100%[===================>]   1.01M   558KB/s    in 1.9s
#
# 2025-06-29 22:20:30 (558 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt08_02.txt’ saved [1059654/1059654]
#
# --2025-06-29 22:20:30--  https://physionet.org/files/gaitpdb/1.0.0/GaPt09_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1098488 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt09_01.txt’
#
# physionet.org/files 100%[===================>]   1.05M   587KB/s    in 1.8s
#
# 2025-06-29 22:20:32 (587 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt09_01.txt’ saved [1098488/1098488]
#
# --2025-06-29 22:20:32--  https://physionet.org/files/gaitpdb/1.0.0/GaPt09_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1088218 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt09_02.txt’
#
# physionet.org/files 100%[===================>]   1.04M   556KB/s    in 1.9s
#
# 2025-06-29 22:20:34 (556 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt09_02.txt’ saved [1088218/1088218]
#
# --2025-06-29 22:20:34--  https://physionet.org/files/gaitpdb/1.0.0/GaPt12_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1092044 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt12_01.txt’
#
# physionet.org/files 100%[===================>]   1.04M   565KB/s    in 1.9s
#
# 2025-06-29 22:20:36 (565 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt12_01.txt’ saved [1092044/1092044]
#
# --2025-06-29 22:20:36--  https://physionet.org/files/gaitpdb/1.0.0/GaPt12_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1093823 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt12_02.txt’
#
# physionet.org/files 100%[===================>]   1.04M   584KB/s    in 1.8s
#
# 2025-06-29 22:20:38 (584 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt12_02.txt’ saved [1093823/1093823]
#
# --2025-06-29 22:20:38--  https://physionet.org/files/gaitpdb/1.0.0/GaPt13_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1117750 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt13_01.txt’
#
# physionet.org/files 100%[===================>]   1.07M   571KB/s    in 1.9s
#
# 2025-06-29 22:20:40 (571 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt13_01.txt’ saved [1117750/1117750]
#
# --2025-06-29 22:20:40--  https://physionet.org/files/gaitpdb/1.0.0/GaPt13_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1121406 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt13_02.txt’
#
# physionet.org/files 100%[===================>]   1.07M   587KB/s    in 1.9s
#
# 2025-06-29 22:20:42 (587 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt13_02.txt’ saved [1121406/1121406]
#
# --2025-06-29 22:20:42--  https://physionet.org/files/gaitpdb/1.0.0/GaPt13_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1142399 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt13_10.txt’
#
# physionet.org/files 100%[===================>]   1.09M   566KB/s    in 2.0s
#
# 2025-06-29 22:20:44 (566 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt13_10.txt’ saved [1142399/1142399]
#
# --2025-06-29 22:20:44--  https://physionet.org/files/gaitpdb/1.0.0/GaPt14_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1089653 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt14_01.txt’
#
# physionet.org/files 100%[===================>]   1.04M   565KB/s    in 1.9s
#
# 2025-06-29 22:20:46 (565 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt14_01.txt’ saved [1089653/1089653]
#
# --2025-06-29 22:20:46--  https://physionet.org/files/gaitpdb/1.0.0/GaPt14_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1071783 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt14_02.txt’
#
# physionet.org/files 100%[===================>]   1.02M   571KB/s    in 1.8s
#
# 2025-06-29 22:20:48 (571 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt14_02.txt’ saved [1071783/1071783]
#
# --2025-06-29 22:20:48--  https://physionet.org/files/gaitpdb/1.0.0/GaPt14_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1084884 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt14_10.txt’
#
# physionet.org/files 100%[===================>]   1.03M   559KB/s    in 1.9s
#
# 2025-06-29 22:20:50 (559 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt14_10.txt’ saved [1084884/1084884]
#
# --2025-06-29 22:20:50--  https://physionet.org/files/gaitpdb/1.0.0/GaPt15_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1084626 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt15_01.txt’
#
# physionet.org/files 100%[===================>]   1.03M   562KB/s    in 1.9s
#
# 2025-06-29 22:20:52 (562 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt15_01.txt’ saved [1084626/1084626]
#
# --2025-06-29 22:20:52--  https://physionet.org/files/gaitpdb/1.0.0/GaPt15_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1077147 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt15_02.txt’
#
# physionet.org/files 100%[===================>]   1.03M   538KB/s    in 2.0s
#
# 2025-06-29 22:20:54 (538 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt15_02.txt’ saved [1077147/1077147]
#
# --2025-06-29 22:20:54--  https://physionet.org/files/gaitpdb/1.0.0/GaPt15_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1086144 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt15_10.txt’
#
# physionet.org/files 100%[===================>]   1.04M   594KB/s    in 1.8s
#
# 2025-06-29 22:20:56 (594 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt15_10.txt’ saved [1086144/1086144]
#
# --2025-06-29 22:20:56--  https://physionet.org/files/gaitpdb/1.0.0/GaPt16_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1117561 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt16_01.txt’
#
# physionet.org/files 100%[===================>]   1.07M   558KB/s    in 2.0s
#
# 2025-06-29 22:20:58 (558 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt16_01.txt’ saved [1117561/1117561]
#
# --2025-06-29 22:20:58--  https://physionet.org/files/gaitpdb/1.0.0/GaPt16_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1117072 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt16_02.txt’
#
# physionet.org/files 100%[===================>]   1.06M   575KB/s    in 1.9s
#
# 2025-06-29 22:21:00 (575 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt16_02.txt’ saved [1117072/1117072]
#
# --2025-06-29 22:21:00--  https://physionet.org/files/gaitpdb/1.0.0/GaPt16_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1123975 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt16_10.txt’
#
# physionet.org/files 100%[===================>]   1.07M   579KB/s    in 1.9s
#
# 2025-06-29 22:21:02 (579 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt16_10.txt’ saved [1123975/1123975]
#
# --2025-06-29 22:21:02--  https://physionet.org/files/gaitpdb/1.0.0/GaPt17_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1138021 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt17_01.txt’
#
# physionet.org/files 100%[===================>]   1.08M   589KB/s    in 1.9s
#
# 2025-06-29 22:21:04 (589 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt17_01.txt’ saved [1138021/1138021]
#
# --2025-06-29 22:21:04--  https://physionet.org/files/gaitpdb/1.0.0/GaPt17_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1129600 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt17_02.txt’
#
# physionet.org/files 100%[===================>]   1.08M   566KB/s    in 1.9s
#
# 2025-06-29 22:21:06 (566 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt17_02.txt’ saved [1129600/1129600]
#
# --2025-06-29 22:21:06--  https://physionet.org/files/gaitpdb/1.0.0/GaPt17_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1163548 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt17_10.txt’
#
# physionet.org/files 100%[===================>]   1.11M   596KB/s    in 1.9s
#
# 2025-06-29 22:21:08 (596 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt17_10.txt’ saved [1163548/1163548]
#
# --2025-06-29 22:21:08--  https://physionet.org/files/gaitpdb/1.0.0/GaPt18_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1129600 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt18_01.txt’
#
# physionet.org/files 100%[===================>]   1.08M   578KB/s    in 1.9s
#
# 2025-06-29 22:21:10 (578 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt18_01.txt’ saved [1129600/1129600]
#
# --2025-06-29 22:21:10--  https://physionet.org/files/gaitpdb/1.0.0/GaPt18_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1111060 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt18_02.txt’
#
# physionet.org/files 100%[===================>]   1.06M   592KB/s    in 1.8s
#
# 2025-06-29 22:21:12 (592 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt18_02.txt’ saved [1111060/1111060]
#
# --2025-06-29 22:21:12--  https://physionet.org/files/gaitpdb/1.0.0/GaPt18_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1127460 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt18_10.txt’
#
# physionet.org/files 100%[===================>]   1.08M   595KB/s    in 1.8s
#
# 2025-06-29 22:21:14 (595 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt18_10.txt’ saved [1127460/1127460]
#
# --2025-06-29 22:21:14--  https://physionet.org/files/gaitpdb/1.0.0/GaPt19_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1104412 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt19_01.txt’
#
# physionet.org/files 100%[===================>]   1.05M   574KB/s    in 1.9s
#
# 2025-06-29 22:21:16 (574 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt19_01.txt’ saved [1104412/1104412]
#
# --2025-06-29 22:21:16--  https://physionet.org/files/gaitpdb/1.0.0/GaPt19_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1100695 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt19_02.txt’
#
# physionet.org/files 100%[===================>]   1.05M   592KB/s    in 1.8s
#
# 2025-06-29 22:21:18 (592 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt19_02.txt’ saved [1100695/1100695]
#
# --2025-06-29 22:21:18--  https://physionet.org/files/gaitpdb/1.0.0/GaPt19_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1104854 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt19_10.txt’
#
# physionet.org/files 100%[===================>]   1.05M   592KB/s    in 1.8s
#
# 2025-06-29 22:21:20 (592 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt19_10.txt’ saved [1104854/1104854]
#
# --2025-06-29 22:21:20--  https://physionet.org/files/gaitpdb/1.0.0/GaPt20_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1130912 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt20_01.txt’
#
# physionet.org/files 100%[===================>]   1.08M   566KB/s    in 2.0s
#
# 2025-06-29 22:21:22 (566 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt20_01.txt’ saved [1130912/1130912]
#
# --2025-06-29 22:21:22--  https://physionet.org/files/gaitpdb/1.0.0/GaPt20_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1115196 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt20_02.txt’
#
# physionet.org/files 100%[===================>]   1.06M   572KB/s    in 1.9s
#
# 2025-06-29 22:21:24 (572 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt20_02.txt’ saved [1115196/1115196]
#
# --2025-06-29 22:21:24--  https://physionet.org/files/gaitpdb/1.0.0/GaPt20_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1138993 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt20_10.txt’
#
# physionet.org/files 100%[===================>]   1.09M   608KB/s    in 1.8s
#
# 2025-06-29 22:21:26 (608 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt20_10.txt’ saved [1138993/1138993]
#
# --2025-06-29 22:21:26--  https://physionet.org/files/gaitpdb/1.0.0/GaPt21_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1095925 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt21_01.txt’
#
# physionet.org/files 100%[===================>]   1.04M   588KB/s    in 1.8s
#
# 2025-06-29 22:21:28 (588 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt21_01.txt’ saved [1095925/1095925]
#
# --2025-06-29 22:21:28--  https://physionet.org/files/gaitpdb/1.0.0/GaPt21_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1104655 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt21_02.txt’
#
# physionet.org/files 100%[===================>]   1.05M   582KB/s    in 1.9s
#
# 2025-06-29 22:21:30 (582 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt21_02.txt’ saved [1104655/1104655]
#
# --2025-06-29 22:21:30--  https://physionet.org/files/gaitpdb/1.0.0/GaPt21_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1111869 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt21_10.txt’
#
# physionet.org/files 100%[===================>]   1.06M   559KB/s    in 1.9s
#
# 2025-06-29 22:21:32 (559 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt21_10.txt’ saved [1111869/1111869]
#
# --2025-06-29 22:21:32--  https://physionet.org/files/gaitpdb/1.0.0/GaPt22_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1098565 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt22_01.txt’
#
# physionet.org/files 100%[===================>]   1.05M   594KB/s    in 1.8s
#
# 2025-06-29 22:21:34 (594 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt22_01.txt’ saved [1098565/1098565]
#
# --2025-06-29 22:21:34--  https://physionet.org/files/gaitpdb/1.0.0/GaPt22_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1104245 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt22_02.txt’
#
# physionet.org/files 100%[===================>]   1.05M   593KB/s    in 1.8s
#
# 2025-06-29 22:21:36 (593 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt22_02.txt’ saved [1104245/1104245]
#
# --2025-06-29 22:21:36--  https://physionet.org/files/gaitpdb/1.0.0/GaPt22_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1119690 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt22_10.txt’
#
# physionet.org/files 100%[===================>]   1.07M   603KB/s    in 1.8s
#
# 2025-06-29 22:21:38 (603 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt22_10.txt’ saved [1119690/1119690]
#
# --2025-06-29 22:21:38--  https://physionet.org/files/gaitpdb/1.0.0/GaPt23_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1167474 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt23_01.txt’
#
# physionet.org/files 100%[===================>]   1.11M   577KB/s    in 2.0s
#
# 2025-06-29 22:21:40 (577 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt23_01.txt’ saved [1167474/1167474]
#
# --2025-06-29 22:21:40--  https://physionet.org/files/gaitpdb/1.0.0/GaPt23_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1167826 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt23_02.txt’
#
# physionet.org/files 100%[===================>]   1.11M   621KB/s    in 1.8s
#
# 2025-06-29 22:21:42 (621 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt23_02.txt’ saved [1167826/1167826]
#
# --2025-06-29 22:21:42--  https://physionet.org/files/gaitpdb/1.0.0/GaPt23_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1188425 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt23_10.txt’
#
# physionet.org/files 100%[===================>]   1.13M   565KB/s    in 2.1s
#
# 2025-06-29 22:21:44 (565 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt23_10.txt’ saved [1188425/1188425]
#
# --2025-06-29 22:21:44--  https://physionet.org/files/gaitpdb/1.0.0/GaPt24_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1091457 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt24_01.txt’
#
# physionet.org/files 100%[===================>]   1.04M   562KB/s    in 1.9s
#
# 2025-06-29 22:21:46 (562 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt24_01.txt’ saved [1091457/1091457]
#
# --2025-06-29 22:21:46--  https://physionet.org/files/gaitpdb/1.0.0/GaPt24_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1086150 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt24_02.txt’
#
# physionet.org/files 100%[===================>]   1.04M   580KB/s    in 1.8s
#
# 2025-06-29 22:21:48 (580 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt24_02.txt’ saved [1086150/1086150]
#
# --2025-06-29 22:21:48--  https://physionet.org/files/gaitpdb/1.0.0/GaPt24_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1102104 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt24_10.txt’
#
# physionet.org/files 100%[===================>]   1.05M   559KB/s    in 1.9s
#
# 2025-06-29 22:21:50 (559 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt24_10.txt’ saved [1102104/1102104]
#
# --2025-06-29 22:21:50--  https://physionet.org/files/gaitpdb/1.0.0/GaPt25_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1086440 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt25_01.txt’
#
# physionet.org/files 100%[===================>]   1.04M   577KB/s    in 1.8s
#
# 2025-06-29 22:21:52 (577 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt25_01.txt’ saved [1086440/1086440]
#
# --2025-06-29 22:21:52--  https://physionet.org/files/gaitpdb/1.0.0/GaPt25_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1067200 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt25_02.txt’
#
# physionet.org/files 100%[===================>]   1.02M   605KB/s    in 1.7s
#
# 2025-06-29 22:21:54 (605 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt25_02.txt’ saved [1067200/1067200]
#
# --2025-06-29 22:21:54--  https://physionet.org/files/gaitpdb/1.0.0/GaPt25_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1083256 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt25_10.txt’
#
# physionet.org/files 100%[===================>]   1.03M   586KB/s    in 1.8s
#
# 2025-06-29 22:21:56 (586 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt25_10.txt’ saved [1083256/1083256]
#
# --2025-06-29 22:21:56--  https://physionet.org/files/gaitpdb/1.0.0/GaPt26_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1126442 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt26_01.txt’
#
# physionet.org/files 100%[===================>]   1.07M   557KB/s    in 2.0s
#
# 2025-06-29 22:21:58 (557 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt26_01.txt’ saved [1126442/1126442]
#
# --2025-06-29 22:21:58--  https://physionet.org/files/gaitpdb/1.0.0/GaPt26_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1120973 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt26_02.txt’
#
# physionet.org/files 100%[===================>]   1.07M   570KB/s    in 1.9s
#
# 2025-06-29 22:22:00 (570 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt26_02.txt’ saved [1120973/1120973]
#
# --2025-06-29 22:22:00--  https://physionet.org/files/gaitpdb/1.0.0/GaPt26_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1136067 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt26_10.txt’
#
# physionet.org/files 100%[===================>]   1.08M   585KB/s    in 1.9s
#
# 2025-06-29 22:22:02 (585 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt26_10.txt’ saved [1136067/1136067]
#
# --2025-06-29 22:22:02--  https://physionet.org/files/gaitpdb/1.0.0/GaPt27_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1128525 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt27_01.txt’
#
# physionet.org/files 100%[===================>]   1.08M   569KB/s    in 1.9s
#
# 2025-06-29 22:22:04 (569 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt27_01.txt’ saved [1128525/1128525]
#
# --2025-06-29 22:22:04--  https://physionet.org/files/gaitpdb/1.0.0/GaPt27_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1131379 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt27_02.txt’
#
# physionet.org/files 100%[===================>]   1.08M   593KB/s    in 1.9s
#
# 2025-06-29 22:22:06 (593 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt27_02.txt’ saved [1131379/1131379]
#
# --2025-06-29 22:22:06--  https://physionet.org/files/gaitpdb/1.0.0/GaPt27_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1159019 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt27_10.txt’
#
# physionet.org/files 100%[===================>]   1.10M   565KB/s    in 2.0s
#
# 2025-06-29 22:22:09 (565 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt27_10.txt’ saved [1159019/1159019]
#
# --2025-06-29 22:22:09--  https://physionet.org/files/gaitpdb/1.0.0/GaPt28_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1158998 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt28_01.txt’
#
# physionet.org/files 100%[===================>]   1.10M   626KB/s    in 1.8s
#
# 2025-06-29 22:22:10 (626 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt28_01.txt’ saved [1158998/1158998]
#
# --2025-06-29 22:22:10--  https://physionet.org/files/gaitpdb/1.0.0/GaPt28_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1157155 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt28_02.txt’
#
# physionet.org/files 100%[===================>]   1.10M   553KB/s    in 2.0s
#
# 2025-06-29 22:22:13 (553 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt28_02.txt’ saved [1157155/1157155]
#
# --2025-06-29 22:22:13--  https://physionet.org/files/gaitpdb/1.0.0/GaPt28_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1164355 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt28_10.txt’
#
# physionet.org/files 100%[===================>]   1.11M   621KB/s    in 1.8s
#
# 2025-06-29 22:22:15 (621 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt28_10.txt’ saved [1164355/1164355]
#
# --2025-06-29 22:22:15--  https://physionet.org/files/gaitpdb/1.0.0/GaPt29_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1076293 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt29_01.txt’
#
# physionet.org/files 100%[===================>]   1.03M   593KB/s    in 1.8s
#
# 2025-06-29 22:22:17 (593 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt29_01.txt’ saved [1076293/1076293]
#
# --2025-06-29 22:22:17--  https://physionet.org/files/gaitpdb/1.0.0/GaPt29_02.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1060787 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt29_02.txt’
#
# physionet.org/files 100%[===================>]   1.01M   580KB/s    in 1.8s
#
# 2025-06-29 22:22:18 (580 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt29_02.txt’ saved [1060787/1060787]
#
# --2025-06-29 22:22:18--  https://physionet.org/files/gaitpdb/1.0.0/GaPt29_10.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1081358 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/GaPt29_10.txt’
#
# physionet.org/files 100%[===================>]   1.03M   591KB/s    in 1.8s
#
# 2025-06-29 22:22:20 (591 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/GaPt29_10.txt’ saved [1081358/1081358]
#
# ...
#
# --2025-06-29 22:27:19--  https://physionet.org/files/gaitpdb/1.0.0/SiPt10_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1068107 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt10_01.txt’
#
# physionet.org/files 100%[===================>]   1.02M   611KB/s    in 1.7s
#
# 2025-06-29 22:27:20 (611 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt10_01.txt’ saved [1068107/1068107]
#
# --2025-06-29 22:27:20--  https://physionet.org/files/gaitpdb/1.0.0/SiPt12_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1092636 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt12_01.txt’
#
# physionet.org/files 100%[===================>]   1.04M   469KB/s    in 2.3s
#
# 2025-06-29 22:27:23 (469 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt12_01.txt’ saved [1092636/1092636]
#
# --2025-06-29 22:27:23--  https://physionet.org/files/gaitpdb/1.0.0/SiPt13_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1091109 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt13_01.txt’
#
# physionet.org/files 100%[===================>]   1.04M   577KB/s    in 1.8s
#
# 2025-06-29 22:27:25 (577 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt13_01.txt’ saved [1091109/1091109]
#
# --2025-06-29 22:27:25--  https://physionet.org/files/gaitpdb/1.0.0/SiPt14_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1042634 (1018K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt14_01.txt’
#
# physionet.org/files 100%[===================>]   1018K   594KB/s    in 1.7s
#
# 2025-06-29 22:27:27 (594 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt14_01.txt’ saved [1042634/1042634]
#
# --2025-06-29 22:27:27--  https://physionet.org/files/gaitpdb/1.0.0/SiPt15_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1102401 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt15_01.txt’
#
# physionet.org/files 100%[===================>]   1.05M   586KB/s    in 1.8s
#
# 2025-06-29 22:27:29 (586 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt15_01.txt’ saved [1102401/1102401]
#
# --2025-06-29 22:27:29--  https://physionet.org/files/gaitpdb/1.0.0/SiPt16_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1073818 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt16_01.txt’
#
# physionet.org/files 100%[===================>]   1.02M   557KB/s    in 1.9s
#
# 2025-06-29 22:27:31 (557 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt16_01.txt’ saved [1073818/1073818]
#
# --2025-06-29 22:27:31--  https://physionet.org/files/gaitpdb/1.0.0/SiPt17_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1068730 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt17_01.txt’
#
# physionet.org/files 100%[===================>]   1.02M   585KB/s    in 1.8s
#
# 2025-06-29 22:27:32 (585 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt17_01.txt’ saved [1068730/1068730]
#
# --2025-06-29 22:27:32--  https://physionet.org/files/gaitpdb/1.0.0/SiPt18_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1120258 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt18_01.txt’
#
# physionet.org/files 100%[===================>]   1.07M   597KB/s    in 1.8s
#
# 2025-06-29 22:27:34 (597 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt18_01.txt’ saved [1120258/1120258]
#
# --2025-06-29 22:27:34--  https://physionet.org/files/gaitpdb/1.0.0/SiPt19_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1087946 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt19_01.txt’
#
# physionet.org/files 100%[===================>]   1.04M   482KB/s    in 2.2s
#
# 2025-06-29 22:27:37 (482 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt19_01.txt’ saved [1087946/1087946]
#
# --2025-06-29 22:27:37--  https://physionet.org/files/gaitpdb/1.0.0/SiPt20_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1125062 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt20_01.txt’
#
# physionet.org/files 100%[===================>]   1.07M   602KB/s    in 1.8s
#
# 2025-06-29 22:27:39 (602 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt20_01.txt’ saved [1125062/1125062]
#
# --2025-06-29 22:27:39--  https://physionet.org/files/gaitpdb/1.0.0/SiPt21_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1094036 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt21_01.txt’
#
# physionet.org/files 100%[===================>]   1.04M   607KB/s    in 1.8s
#
# 2025-06-29 22:27:41 (607 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt21_01.txt’ saved [1094036/1094036]
#
# --2025-06-29 22:27:41--  https://physionet.org/files/gaitpdb/1.0.0/SiPt22_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1107687 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt22_01.txt’
#
# physionet.org/files 100%[===================>]   1.06M   580KB/s    in 1.9s
#
# 2025-06-29 22:27:43 (580 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt22_01.txt’ saved [1107687/1107687]
#
# --2025-06-29 22:27:43--  https://physionet.org/files/gaitpdb/1.0.0/SiPt23_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1088669 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt23_01.txt’
#
# physionet.org/files 100%[===================>]   1.04M   578KB/s    in 1.8s
#
# 2025-06-29 22:27:45 (578 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt23_01.txt’ saved [1088669/1088669]
#
# --2025-06-29 22:27:45--  https://physionet.org/files/gaitpdb/1.0.0/SiPt24_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1050002 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt24_01.txt’
#
# physionet.org/files 100%[===================>]   1.00M   560KB/s    in 1.8s
#
# 2025-06-29 22:27:46 (560 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt24_01.txt’ saved [1050002/1050002]
#
# --2025-06-29 22:27:46--  https://physionet.org/files/gaitpdb/1.0.0/SiPt25_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1111660 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt25_01.txt’
#
# physionet.org/files 100%[===================>]   1.06M   615KB/s    in 1.8s
#
# 2025-06-29 22:27:48 (615 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt25_01.txt’ saved [1111660/1111660]
#
# --2025-06-29 22:27:48--  https://physionet.org/files/gaitpdb/1.0.0/SiPt27_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1138710 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt27_01.txt’
#
# physionet.org/files 100%[===================>]   1.09M   557KB/s    in 2.0s
#
# 2025-06-29 22:27:50 (557 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt27_01.txt’ saved [1138710/1138710]
#
# --2025-06-29 22:27:50--  https://physionet.org/files/gaitpdb/1.0.0/SiPt28_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1108191 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt28_01.txt’
#
# physionet.org/files 100%[===================>]   1.06M   595KB/s    in 1.8s
#
# 2025-06-29 22:27:52 (595 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt28_01.txt’ saved [1108191/1108191]
#
# --2025-06-29 22:27:52--  https://physionet.org/files/gaitpdb/1.0.0/SiPt29_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1151770 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt29_01.txt’
#
# physionet.org/files 100%[===================>]   1.10M   569KB/s    in 2.0s
#
# 2025-06-29 22:27:55 (569 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt29_01.txt’ saved [1151770/1151770]
#
# --2025-06-29 22:27:55--  https://physionet.org/files/gaitpdb/1.0.0/SiPt30_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1109882 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt30_01.txt’
#
# physionet.org/files 100%[===================>]   1.06M   550KB/s    in 2.0s
#
# 2025-06-29 22:27:57 (550 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt30_01.txt’ saved [1109882/1109882]
#
# --2025-06-29 22:27:57--  https://physionet.org/files/gaitpdb/1.0.0/SiPt31_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1142398 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt31_01.txt’
#
# physionet.org/files 100%[===================>]   1.09M   567KB/s    in 2.0s
#
# 2025-06-29 22:27:59 (567 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt31_01.txt’ saved [1142398/1142398]
#
# --2025-06-29 22:27:59--  https://physionet.org/files/gaitpdb/1.0.0/SiPt32_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1098233 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt32_01.txt’
#
# physionet.org/files 100%[===================>]   1.05M   565KB/s    in 1.9s
#
# 2025-06-29 22:28:01 (565 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt32_01.txt’ saved [1098233/1098233]
#
# --2025-06-29 22:28:01--  https://physionet.org/files/gaitpdb/1.0.0/SiPt33_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1107374 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt33_01.txt’
#
# physionet.org/files 100%[===================>]   1.06M   550KB/s    in 2.0s
#
# 2025-06-29 22:28:03 (550 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt33_01.txt’ saved [1107374/1107374]
#
# --2025-06-29 22:28:03--  https://physionet.org/files/gaitpdb/1.0.0/SiPt34_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1055122 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt34_01.txt’
#
# physionet.org/files 100%[===================>]   1.01M   581KB/s    in 1.8s
#
# 2025-06-29 22:28:05 (581 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt34_01.txt’ saved [1055122/1055122]
#
# --2025-06-29 22:28:05--  https://physionet.org/files/gaitpdb/1.0.0/SiPt35_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1082746 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt35_01.txt’
#
# physionet.org/files 100%[===================>]   1.03M   560KB/s    in 1.9s
#
# 2025-06-29 22:28:07 (560 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt35_01.txt’ saved [1082746/1082746]
#
# --2025-06-29 22:28:07--  https://physionet.org/files/gaitpdb/1.0.0/SiPt36_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1075365 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt36_01.txt’
#
# physionet.org/files 100%[===================>]   1.03M   587KB/s    in 1.8s
#
# 2025-06-29 22:28:09 (587 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt36_01.txt’ saved [1075365/1075365]
#
# --2025-06-29 22:28:09--  https://physionet.org/files/gaitpdb/1.0.0/SiPt37_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1066511 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt37_01.txt’
#
# physionet.org/files 100%[===================>]   1.02M   616KB/s    in 1.7s
#
# 2025-06-29 22:28:10 (616 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt37_01.txt’ saved [1066511/1066511]
#
# --2025-06-29 22:28:10--  https://physionet.org/files/gaitpdb/1.0.0/SiPt38_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1053046 (1.0M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt38_01.txt’
#
# physionet.org/files 100%[===================>]   1.00M   560KB/s    in 1.8s
#
# 2025-06-29 22:28:12 (560 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt38_01.txt’ saved [1053046/1053046]
#
# --2025-06-29 22:28:12--  https://physionet.org/files/gaitpdb/1.0.0/SiPt39_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1142380 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt39_01.txt’
#
# physionet.org/files 100%[===================>]   1.09M   556KB/s    in 2.0s
#
# 2025-06-29 22:28:15 (556 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt39_01.txt’ saved [1142380/1142380]
#
# --2025-06-29 22:28:15--  https://physionet.org/files/gaitpdb/1.0.0/SiPt40_01.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 1128794 (1.1M) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/SiPt40_01.txt’
#
# physionet.org/files 100%[===================>]   1.08M   578KB/s    in 1.9s
#
# 2025-06-29 22:28:17 (578 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/SiPt40_01.txt’ saved [1128794/1128794]
#
# --2025-06-29 22:28:17--  https://physionet.org/files/gaitpdb/1.0.0/demographics.html
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 106031 (104K) [text/html]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/demographics.html’
#
# physionet.org/files 100%[===================>] 103.55K   675KB/s    in 0.2s
#
# 2025-06-29 22:28:17 (675 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/demographics.html’ saved [106031/106031]
#
# --2025-06-29 22:28:17--  https://physionet.org/files/gaitpdb/1.0.0/demographics.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 15665 (15K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/demographics.txt’
#
# physionet.org/files 100%[===================>]  15.30K  --.-KB/s    in 0s
#
# 2025-06-29 22:28:17 (275 MB/s) - ‘physionet.org/files/gaitpdb/1.0.0/demographics.txt’ saved [15665/15665]
#
# --2025-06-29 22:28:17--  https://physionet.org/files/gaitpdb/1.0.0/demographics.xls
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 47104 (46K) [application/vnd.ms-excel]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/demographics.xls’
#
# physionet.org/files 100%[===================>]  46.00K  --.-KB/s    in 0.05s
#
# 2025-06-29 22:28:17 (917 KB/s) - ‘physionet.org/files/gaitpdb/1.0.0/demographics.xls’ saved [47104/47104]
#
# --2025-06-29 22:28:17--  https://physionet.org/files/gaitpdb/1.0.0/format.txt
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 2339 (2.3K) [text/plain]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/format.txt’
#
# physionet.org/files 100%[===================>]   2.28K  --.-KB/s    in 0s
#
# 2025-06-29 22:28:17 (866 MB/s) - ‘physionet.org/files/gaitpdb/1.0.0/format.txt’ saved [2339/2339]
#
# --2025-06-29 22:28:17--  https://physionet.org/files/gaitpdb/1.0.0/gaitpd.png
# Reusing existing connection to physionet.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 22068 (22K) [image/png]
# Saving to: ‘physionet.org/files/gaitpdb/1.0.0/gaitpd.png’
#
# physionet.org/files 100%[===================>]  21.55K  --.-KB/s    in 0.008s
#
# 2025-06-29 22:28:17 (2.62 MB/s) - ‘physionet.org/files/gaitpdb/1.0.0/gaitpd.png’ saved [22068/22068]
#
# FINISHED --2025-06-29 22:28:17--
# Total wall clock time: 9m 17s
# Downloaded: 314 files, 288M in 8m 36s (572 KB/s)

# %% [markdown]
# ## Listar arquivos baixados

# %%
# !ls -R physionet.org/files/gaitpdb/1.0.0/
# Out:
# physionet.org/files/gaitpdb/1.0.0/:
# demographics.html  GaPt15_10.txt  JuCo08_01.txt  JuPt13_01.txt	 SiCo05_01.txt
# demographics.txt   GaPt16_01.txt  JuCo09_01.txt  JuPt14_01.txt	 SiCo06_01.txt
# demographics.xls   GaPt16_02.txt  JuCo11_01.txt  JuPt15_01.txt	 SiCo07_01.txt
# format.txt	   GaPt16_10.txt  JuCo12_01.txt  JuPt15_02.txt	 SiCo08_01.txt
# GaCo01_01.txt	   GaPt17_01.txt  JuCo13_01.txt  JuPt15_03.txt	 SiCo09_01.txt
# GaCo02_01.txt	   GaPt17_02.txt  JuCo14_01.txt  JuPt15_04.txt	 SiCo10_01.txt
# GaCo02_02.txt	   GaPt17_10.txt  JuCo15_01.txt  JuPt15_05.txt	 SiCo11_01.txt
# GaCo03_01.txt	   GaPt18_01.txt  JuCo16_01.txt  JuPt15_06.txt	 SiCo12_01.txt
# GaCo03_02.txt	   GaPt18_02.txt  JuCo17_01.txt  JuPt15_07.txt	 SiCo13_01.txt
# GaCo04_01.txt	   GaPt18_10.txt  JuCo18_01.txt  JuPt16_01.txt	 SiCo14_01.txt
# GaCo04_02.txt	   GaPt19_01.txt  JuCo19_01.txt  JuPt17_01.txt	 SiCo15_01.txt
# GaCo05_01.txt	   GaPt19_02.txt  JuCo20_01.txt  JuPt18_01.txt	 SiCo16_01.txt
# GaCo05_02.txt	   GaPt19_10.txt  JuCo21_01.txt  JuPt19_01.txt	 SiCo17_01.txt
# GaCo06_01.txt	   GaPt20_01.txt  JuCo22_01.txt  JuPt20_01.txt	 SiCo18_01.txt
# GaCo06_02.txt	   GaPt20_02.txt  JuCo23_01.txt  JuPt20_02.txt	 SiCo19_01.txt
# GaCo07_01.txt	   GaPt20_10.txt  JuCo24_01.txt  JuPt20_03.txt	 SiCo20_01.txt
# GaCo07_02.txt	   GaPt21_01.txt  JuCo25_01.txt  JuPt20_04.txt	 SiCo21_01.txt
# GaCo08_01.txt	   GaPt21_02.txt  JuCo26_01.txt  JuPt20_05.txt	 SiCo22_01.txt
# GaCo08_02.txt	   GaPt21_10.txt  JuPt01_01.txt  JuPt20_06.txt	 SiCo23_01.txt
# GaCo09_01.txt	   GaPt22_01.txt  JuPt01_02.txt  JuPt20_07.txt	 SiCo24_01.txt
# GaCo09_02.txt	   GaPt22_02.txt  JuPt01_03.txt  JuPt21_01.txt	 SiCo25_01.txt
# GaCo10_01.txt	   GaPt22_10.txt  JuPt01_04.txt  JuPt21_02.txt	 SiCo26_01.txt
# GaCo10_02.txt	   GaPt23_01.txt  JuPt01_05.txt  JuPt21_03.txt	 SiCo27_01.txt
# GaCo11_01.txt	   GaPt23_02.txt  JuPt01_06.txt  JuPt21_04.txt	 SiCo28_01.txt
# GaCo12_01.txt	   GaPt23_10.txt  JuPt02_01.txt  JuPt21_05.txt	 SiCo29_01.txt
# GaCo13_01.txt	   GaPt24_01.txt  JuPt03_01.txt  JuPt21_06.txt	 SiCo30_01.txt
# GaCo13_02.txt	   GaPt24_02.txt  JuPt03_02.txt  JuPt21_07.txt	 SiPt02_01.txt
# GaCo13_10.txt	   GaPt24_10.txt  JuPt03_03.txt  JuPt22_01.txt	 SiPt04_01.txt
# GaCo14_01.txt	   GaPt25_01.txt  JuPt03_04.txt  JuPt23_01.txt	 SiPt05_01.txt
# GaCo14_02.txt	   GaPt25_02.txt  JuPt03_05.txt  JuPt23_02.txt	 SiPt07_01.txt
# GaCo14_10.txt	   GaPt25_10.txt  JuPt03_06.txt  JuPt23_03.txt	 SiPt08_01.txt
# GaCo15_01.txt	   GaPt26_01.txt  JuPt03_07.txt  JuPt23_04.txt	 SiPt09_01.txt
# GaCo15_02.txt	   GaPt26_02.txt  JuPt04_01.txt  JuPt23_05.txt	 SiPt10_01.txt
# GaCo15_10.txt	   GaPt26_10.txt  JuPt05_01.txt  JuPt23_06.txt	 SiPt12_01.txt
# GaCo16_01.txt	   GaPt27_01.txt  JuPt06_01.txt  JuPt23_07.txt	 SiPt13_01.txt
# GaCo16_02.txt	   GaPt27_02.txt  JuPt06_02.txt  JuPt24_01.txt	 SiPt14_01.txt
# GaCo16_10.txt	   GaPt27_10.txt  JuPt06_03.txt  JuPt24_02.txt	 SiPt15_01.txt
# GaCo17_01.txt	   GaPt28_01.txt  JuPt06_04.txt  JuPt25_01.txt	 SiPt16_01.txt
# GaCo17_02.txt	   GaPt28_02.txt  JuPt06_05.txt  JuPt26_01.txt	 SiPt17_01.txt
# GaCo17_10.txt	   GaPt28_10.txt  JuPt06_06.txt  JuPt26_03.txt	 SiPt18_01.txt
# GaCo22_01.txt	   GaPt29_01.txt  JuPt06_07.txt  JuPt26_04.txt	 SiPt19_01.txt
# GaCo22_10.txt	   GaPt29_02.txt  JuPt07_01.txt  JuPt26_05.txt	 SiPt20_01.txt
# gaitpd.png	   GaPt29_10.txt  JuPt08_01.txt  JuPt26_06.txt	 SiPt21_01.txt
# GaPt03_01.txt	   GaPt30_01.txt  JuPt09_01.txt  JuPt26_07.txt	 SiPt22_01.txt
# GaPt04_01.txt	   GaPt30_02.txt  JuPt09_02.txt  JuPt27_01.txt	 SiPt23_01.txt
# GaPt05_01.txt	   GaPt30_10.txt  JuPt09_03.txt  JuPt28_01.txt	 SiPt24_01.txt
# GaPt06_01.txt	   GaPt31_01.txt  JuPt09_04.txt  JuPt28_02.txt	 SiPt25_01.txt
# GaPt07_01.txt	   GaPt31_02.txt  JuPt09_05.txt  JuPt28_03.txt	 SiPt27_01.txt
# GaPt07_02.txt	   GaPt31_10.txt  JuPt10_01.txt  JuPt28_04.txt	 SiPt28_01.txt
# GaPt08_01.txt	   GaPt32_01.txt  JuPt10_02.txt  JuPt28_05.txt	 SiPt29_01.txt
# GaPt08_02.txt	   GaPt32_02.txt  JuPt10_03.txt  JuPt28_06.txt	 SiPt30_01.txt
# GaPt09_01.txt	   GaPt32_10.txt  JuPt10_04.txt  JuPt28_07.txt	 SiPt31_01.txt
# GaPt09_02.txt	   GaPt33_01.txt  JuPt10_05.txt  JuPt29_01.txt	 SiPt32_01.txt
# GaPt12_01.txt	   GaPt33_02.txt  JuPt10_06.txt  JuPt29_02.txt	 SiPt33_01.txt
# GaPt12_02.txt	   GaPt33_10.txt  JuPt10_07.txt  JuPt29_03.txt	 SiPt34_01.txt
# GaPt13_01.txt	   index.html	  JuPt11_01.txt  JuPt29_04.txt	 SiPt35_01.txt
# GaPt13_02.txt	   JuCo01_01.txt  JuPt11_02.txt  JuPt29_05.txt	 SiPt36_01.txt
# GaPt13_10.txt	   JuCo02_01.txt  JuPt11_03.txt  JuPt29_06.txt	 SiPt37_01.txt
# GaPt14_01.txt	   JuCo03_01.txt  JuPt11_04.txt  JuPt29_07.txt	 SiPt38_01.txt
# GaPt14_02.txt	   JuCo04_01.txt  JuPt11_05.txt  SHA256SUMS.txt  SiPt39_01.txt
# GaPt14_10.txt	   JuCo05_01.txt  JuPt11_06.txt  SiCo01_01.txt	 SiPt40_01.txt
# GaPt15_01.txt	   JuCo06_01.txt  JuPt11_07.txt  SiCo03_01.txt
# GaPt15_02.txt	   JuCo07_01.txt  JuPt12_01.txt  SiCo04_01.txt

# %% [markdown]
# ## Carregar os dados p df

# %%
import pandas as pd

# Pegar primeiro esse GaCo01_01
file_path = 'physionet.org/files/gaitpdb/1.0.0/GaCo01_01.txt'

# Arrumar/Renomear as colunas
# vai ser L de Left e R de Right
column_names = [
    'Time',
    'L_VGRF_1', 'L_VGRF_2', 'L_VGRF_3', 'L_VGRF_4', 'L_VGRF_5', 'L_VGRF_6',
    'L_VGRF_7', 'L_VGRF_8',
    'R_VGRF_1', 'R_VGRF_2', 'R_VGRF_3', 'R_VGRF_4', 'R_VGRF_5', 'R_VGRF_6',
    'R_VGRF_7', 'R_VGRF_8',
    'Total_L_Foot_Force',
    'Total_R_Foot_Force'
]

df = pd.read_csv(file_path, sep='\s+', header=None, names=column_names)

print(df.head())

print(df.info())
# Out:
#    Time  L_VGRF_1  L_VGRF_2  L_VGRF_3  L_VGRF_4  L_VGRF_5  L_VGRF_6  L_VGRF_7  \
# 0  0.00     199.1     87.34     91.08     24.09     21.12     87.67     87.23
# 1  0.01     199.1     87.34     91.08     24.09     21.12     87.67     87.23
# 2  0.02     199.1     87.34     91.08     24.09     21.12     87.67     87.23
# 3  0.03     199.1     87.34     91.08     24.09     21.12     87.67     89.10
# 4  0.04     199.1     87.34     91.08     24.09     21.12     87.67     87.23
#
#    L_VGRF_8  R_VGRF_1  R_VGRF_2  R_VGRF_3  R_VGRF_4  R_VGRF_5  R_VGRF_6  \
# 0     64.57     163.9     79.86    112.42     50.82     13.75    102.74
# 1     64.57     163.9     79.86    112.42     50.82     13.75    102.74
# 2     62.59     163.9     79.86    112.42     50.82     13.75    102.74
# 3     64.57     163.9     77.55    112.42     48.07     13.75    105.49
# 4     62.59     163.9     77.55    112.42     50.82     13.75    105.49
#
#    R_VGRF_7  R_VGRF_8  Total_L_Foot_Force  Total_R_Foot_Force
# 0    144.98     79.53              662.20              748.00
# 1    144.98     79.53              662.20              748.00
# 2    144.98     79.53              660.22              748.00
# 3    144.98     79.53              664.07              745.69
# 4    144.98     79.53              660.22              748.44
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12119 entries, 0 to 12118
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Time                12119 non-null  float64
#  1   L_VGRF_1            12119 non-null  float64
#  2   L_VGRF_2            12119 non-null  float64
#  3   L_VGRF_3            12119 non-null  float64
#  4   L_VGRF_4            12119 non-null  float64
#  5   L_VGRF_5            12119 non-null  float64
#  6   L_VGRF_6            12119 non-null  float64
#  7   L_VGRF_7            12119 non-null  float64
#  8   L_VGRF_8            12119 non-null  float64
#  9   R_VGRF_1            12119 non-null  float64
#  10  R_VGRF_2            12119 non-null  float64
#  11  R_VGRF_3            12119 non-null  float64
#  12  R_VGRF_4            12119 non-null  float64
#  13  R_VGRF_5            12119 non-null  float64
#  14  R_VGRF_6            12119 non-null  float64
#  15  R_VGRF_7            12119 non-null  float64
#  16  R_VGRF_8            12119 non-null  float64
#  17  Total_L_Foot_Force  12119 non-null  float64
#  18  Total_R_Foot_Force  12119 non-null  float64
# dtypes: float64(19)
# memory usage: 1.8 MB
# None
